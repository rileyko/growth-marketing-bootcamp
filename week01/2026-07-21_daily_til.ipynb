# %% [markdown]
# **2026.07.21 · 새로운 방향을 시작하며**

# %% [markdown]
# ## 오늘의 핵심
#
# 오리엔테이션에서 앞으로 배우게 될 내용과 진행할 프로젝트의 큰 흐름을 소개받았습니다. 아직은 시작 단계지만, 익숙한 데이터 경험을 사람의 선택과 마케팅 행동으로 연결하는 연습을 할 수 있겠다는 기대가 생겼습니다.

# %% [markdown]
# ## 첫날의 기록
#
# ### 과정과 프로젝트 소개를 들으며
#
# 앞으로 배우게 될 내용과 프로젝트를 간단히 소개받았습니다. 이전에는 데이터를 정리하고 보여주는 일에 익숙했다면, 이번에는 그 안에 있는 사람들이 왜 그렇게 생각하고 선택하는지 더 가까이에서 살펴볼 수 있을 것 같았습니다.

# %% [markdown]
# ## 내가 기대하는 것
#
# 도구를 하나 더 배우는 데서 끝내기보다 소비자의 반응에서 질문을 찾고, 확인한 이유를 메시지와 콘텐츠로 옮기는 과정을 직접 경험해보고 싶습니다. 익숙한 분석 경험은 앞에 내세우기보다 판단을 돕는 근거로 활용하고, 프로젝트를 거치며 마케터로서의 언어와 실행 경험을 쌓는 것이 목표입니다.

# %% [markdown]
# ## 다음 액션
#
# - 수업에서 궁금해진 질문과 내 생각을 그날의 기록으로 남깁니다.
# - 프로젝트에서는 분석 결과보다 그 결과가 어떤 마케팅 판단으로 이어졌는지를 확인합니다.
