# %% [markdown]
# # 그로스 마케팅 분석 프로젝트
#
# > week07 portfolio note · Growth Marketing Project
#
# ## 학습 목표
#
# - 핵심 개념을 내 언어로 설명합니다.
# - 분석 또는 실습 과정을 재현 가능하게 기록합니다.
# - 결과가 마케팅 의사결정에 주는 의미를 해석합니다.
#
# ## 기록 방향
#
# 문제 정의, 분석 과정, 결과, 인사이트와 다음 액션을 중심으로 정리합니다.

# %% [markdown]
# ## 핵심 개념
#
# 강의를 들으며 개념과 예시를 정리하세요.

# %%
# 공통 분석 환경
from pathlib import Path

DATA_DIR = Path("../data")

# %% [markdown]
# ## 실습
#
# 문제 정의 → 데이터 확인 → 분석 → 해석 순서로 기록하세요.

# %%
# 실습 코드를 작성하세요.

# %% [markdown]
# ## 배운 점과 다음 액션
#
# - 오늘 새롭게 이해한 것:
# - 아직 헷갈리는 것:
# - 실제 마케팅 업무에 적용할 아이디어:
# - 다음에 보완할 것:
