# %% [markdown]
# # 취업·AI·데이터 직무 특강
#
# - Notion 수업 노트: 수업 당일 링크를 입력하세요.

# %% [markdown]
# ## 수업 기록
#
# > 같은 날짜·주제의 Notion 기록을 이 셀에 Markdown으로 합쳐 넣습니다.

# %% [markdown]
# ## 실습 코드

# %%
# 공통 분석 환경
from pathlib import Path

DATA_DIR = Path("../data")

# %%
# 실습 코드를 작성하세요.
